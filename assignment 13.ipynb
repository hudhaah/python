# %%
class rectangle():
    def get(self,l,b):
        self.l=l
        self.b=b
    def area(self,l,b):
        return l*b
    def perimeter(self,l,b):
        return 2*(l+b)
r1=rectangle()
r2=rectangle()
l1=int(input("Enter length of rectangle 1:"))
b1=int(input("Enter breadth of rectangle 1:"))
l2=int(input("Enter length of rectangle 2:"))
b2=int(input("Enter breadth of rectangle 2:"))
p=r1.area(l1,b1)
q=r2.area(l2,b2)
print("Area of rectangle 1 is",p)
print("Area of rectangle 2 is",q)
if(p>q):
     print("Rectangle 1 is greater")
elif(p<q):
     print("Rectangle 2 is greater")
else:
     print("Rectangles are equal")
# Out:
# Enter length of rectangle 1:4
# Enter breadth of rectangle 1:1
# Enter length of rectangle 2:5
# Enter breadth of rectangle 2:6
# Area of rectangle 1 is 4
# Area of rectangle 2 is 30
# Rectangle 2 is greater

# %%
#bank account
class bankaccount:
    def __init__(self,a_name,a_no,a_type,a_balance):
        self.acc_name=a_name
        self.acc_no=a_no
        self.acc_type=a_type
        self.acc_balance=a_balance
    def deposit(self,a_deposit):
        print("Initial balance:",self.acc_balance)
        self.acc_balance+=a_deposit
        print(a_deposit,"is deposited")
        print("Current balance:",self.acc_balance)
    def withdraw(self):
        self.amount=int(input("Withdraw amount:"))
        print("Initial balance:",self.acc_balance)
        if self.amount>self.acc_balance:
            print("You dont have enough balance to withdraw!!")
            print("Current balance:",self.acc_balance)
        else:
            print(self.amount,"is withdrawed")
            self.accc_balance-=self.amount
            print("Current balance:",self.acc_balance)
    def acc_info(self):
        print("Account holder name:",self.acc_name)
        print("Account number",self.acc_no)
        print("Account type:",self.acc_type)
        print("Account balance:",self.acc_balance)
name=input("Enter name:")
no=int(input("Enter account no:"))
type=input("Enter account type:")
bal=int(input("Enter initial balance:"))
holder=bankaccount(name,no,type,bal)
while(True):
        ch=int(input("1.Deposit\n2.Withdraw\n3.Account info\n4.Exit\nChoose your opton:"))
        if ch==1:
            amount=int(input("Deposit amount:"))
            holder.deposit(amount)
        elif ch==2:
            holder.withdraw()
        elif ch==3:
            holder.acc_info()
        else:
            print("Exiting..")
            break;
# Out:
# Enter name:hudha
# Enter account no:4523
# Enter account type:savings
# Enter initial balance:25000
# 1.Deposit
# 2.Withdraw
# 3.Account info
# 4.Exit
# Choose your opton:1
# Deposit amount:500
# Initial balance: 25000
# 500 is deposited
# Current balance: 25500
# 1.Deposit
# 2.Withdraw
# 3.Account info
# 4.Exit
# Choose your opton:2
# Withdraw amount:200
# Initial balance: 25500
# 200 is withdrawed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 39
#      37     holder.deposit(amount)
#      38 elif ch==2:
# ---> 39     holder.withdraw()
#      40 elif ch==3:
#      41     holder.acc_info()
#
# Cell In[2], line 21, in bankaccount.withdraw(self)
#      19 else:
#      20     print(self.amount,"is withdrawed")
# ---> 21     self.accc_balance-=self.amount
#      22     print("Current balance:",self.acc_balance)
#
# AttributeError: 'bankaccount' object has no attribute 'accc_balance'

# %%
class publisher:
    def __init__(self,pname):
        self.pubname=pname
    def display1(self):
        print("Book details:\nPublisher name=",self.pubname)
class book(publisher):
    def __init__(self,pname,bname,author):
        self.title=bname
        self.auth=author
        publisher.__init__(self,pname)
    def display2(self):
        print("Title=",self.title)
        print("Author=",self.auth)
class python(book):
    def __init__(self,pname,title,au,price,np):
        self.rate=price
        self.nop=np
        book.__init__(self,pname,title,au)
    def display3(self):
        print("Rate=",self.rate)
        print("No.of pages=",self.nop)
p=input("Enter publisher name:")
b=input("Enter book name:")
a=input("Enter author name:")
r=int(input("Enter rate of book:"))
n=int(input("Enter no. of pages:"))
a=python(p,b,a,r,n)
a.display1()
a.display2()
a.display3()
# Out:
# Enter publisher name:hudha
# Enter book name:book
# Enter author name:fathima
# Enter rate of book:500
# Enter no. of pages:845
# Book details:
# Publisher name= hudha
# Title= book
# Author= fathima
# Rate= 500
# No.of pages= 845

# %%
class rectangle:
    def __init__(self,l,w):
        self.length=l
        self.width=w
        self.a=l*w
    def __gt__(self,other):
        if self.a<other.a:
            print("Rectangle 1 is greater")
l1=int(input("Enter length of rectangle 1:"))
w1=int(input("Enter width of rectangle 1:"))
l2=int(input("Enter length of rectangle 2:"))
w2=int(input("Enter width of rectangle 2:"))
r1=rectangle(l1,w1)
r2=rectangle(l2,w2)
r1<r2
# Out:
# Enter length of rectangle 1:4
# Enter width of rectangle 1:5
# Enter length of rectangle 2:6
# Enter width of rectangle 2:3
# Rectangle 1 is greater

# %%
#bankaccout
class bankaccount:
    def __init__(self,a_name, a_no,a_type,a_balance):
        self.acc_name=a_name
        self.acc_no=a_no
        self.acc_type=a_type
        self.acc_balance=a_balance
    def deposit(self,a_deposit):
        print("initial balance:",self.acc_balance)
        self.acc_balance+=a_deposit
        print(a_deposit,"is deposited")
        print("current balance:",self.acc_balance)
    def withdraw(self):
        self.amount=int(input("withdraw amount:"))
        print("initial balace:",self.acc_balance)
        if self.amount>self.acc_balance:
            print("you dont have enought balace to withdraw !!")
            print("Current balaced:",self.acc_balace)
        else:
            print(self.amount,"is withdrawed")
            self.acc_balance-=self.amount
            print("current balance:",self.acc_balance)
    def acc_info(self):
        print("Account holder Name:",self.acc_name)
        print("Account Number:",self.acc_no)
        print("Account Type:",self.acc_type)
        print("Account Balance:",self.acc_balance)
name=input("Enter name:")
no=int(input("Enter account number:"))
type=input("Enter account type:")
bal=int(input("Enter initial balance:"))
holder=bankaccount(name,no,type,bal)
while(True):
        ch=int(input("1. Deposit\n 2. Withdraw\n3. Account info\n4.Exit\nChoose your option: "))
        if ch==1:
            amount=int(input("Deposit amount: "))
            holder.deposit(amount)
        elif ch==2:
            holder.withdraw()
        elif ch==3:
            holder.acc_info()
        else:
            print("Exiting...")
            break
# Out:
# Enter name:hudha
# Enter account number:56565
# Enter account type:savings
# Enter initial balance:24000
# 1. Deposit
#  2. Withdraw
# 3. Account info
# 4.Exit
# Choose your option: 1
# Deposit amount: 450
# initial balance: 24000
# 450 is deposited
# current balance: 24450
# 1. Deposit
#  2. Withdraw
# 3. Account info
# 4.Exit
# Choose your option: 2
# withdraw amount:450
# initial balace: 24450
# 450 is withdrawed
# current balance: 24000
# 1. Deposit
#  2. Withdraw
# 3. Account info
# 4.Exit
# Choose your option: 3
# Account holder Name: hudha
# Account Number: 56565
# Account Type: savings
# Account Balance: 24000
